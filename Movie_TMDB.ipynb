# %% [markdown]
# <a href="https://colab.research.google.com/github/FabriceD1/TMDB_API/blob/main/Movie_TMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Import Library to Make Requests

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %% [markdown]
# # Step 2: Get TMDB Authorization Token
#
# https://www.themoviedb.org/settings/api

# %%
token_string = "BQBNE7B0ZgdlXR-WUCEBWDCrqlAw1uZogSPps_KmWoCa404ROqg43Djdiiz1n7GMxoqSf5xjake8SU-53rGK_8xDQHvDDiZbdMwYMJMk1iqqZpOKbHJXYadVvONINdWpN1GitOMKCbTbj0hKS3r4m8W7gnedybqkZuRiwnbQ1yc"
token = "Bearer "+token_string
token
# Out:
# 'Bearer BQBNE7B0ZgdlXR-WUCEBWDCrqlAw1uZogSPps_KmWoCa404ROqg43Djdiiz1n7GMxoqSf5xjake8SU-53rGK_8xDQHvDDiZbdMwYMJMk1iqqZpOKbHJXYadVvONINdWpN1GitOMKCbTbj0hKS3r4m8W7gnedybqkZuRiwnbQ1yc'

# %% [markdown]
# # Get Movie Details of Popular Movies

# %%
base_url = 'https://api.themoviedb.org/3/movie/popular?api_key=e93793ba5e52b020648e1f1544b82e55&language=en-US'
headers = {'Authorization': token, 'User-Agent': 'TMDB App'}
response = requests.get(base_url, headers=headers)
popular = response.json()

# %%
pprint(popular)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/bQXAqRx2Fgc46uCVWgoPz5L5Dtr.jpg',
#               'genre_ids': [28, 14, 878],
#               'id': 436270,
#               'original_language': 'en',
#               'original_title': 'Black Adam',
#               'overview': 'Nearly 5,000 years after he was bestowed with the '
#                           'almighty powers of the Egyptian gods—and imprisoned '
#                           'just as quickly—Black Adam is freed from his '
#                           'earthly tomb, ready to unleash his unique form of '
#                           'justice on the modern world.',
#               'popularity': 4418.006,
#               'poster_path': '/pFlaoHTZeyNkG83vxsAJiGzfSsa.jpg',
#               'release_date': '2022-10-19',
#               'title': 'Black Adam',
#               'video': False,
#               'vote_average': 7.2,
#               'vote_count': 3044},
#              {'adult': False,
#               'backdrop_path': '/198vrF8k7mfQ4FjDJsBmdQcaiyq.jpg',
#               'genre_ids': [878, 28, 12],
#               'id': 76600,
#               'original_language': 'en',
#               'original_title': 'Avatar: The Way of Water',
#               'overview': 'Set more than a decade after the events of the '
#                           'first film, learn the story of the Sully family '
#                           '(Jake, Neytiri, and their kids), the trouble that '
#                           'follows them, the lengths they go to keep each '
#                           'other safe, the battles they fight to stay alive, '
#                           'and the tragedies they endure.',
#               'popularity': 5132.775,
#               'poster_path': '/94xxm5701CzOdJdUEdIuwqZaowx.jpg',
#               'release_date': '2022-12-14',
#               'title': 'Avatar: The Way of Water',
#               'video': False,
#               'vote_average': 8.1,
#               'vote_count': 684},
#              {'adult': False,
#               'backdrop_path': '/53BC9F2tpZnsGno2cLhzvGprDYS.jpg',
#               'genre_ids': [14, 28, 12],
#               'id': 736526,
#               'original_language': 'no',
#               'original_title': 'Troll',
#               'overview': 'Deep inside the mountain of Dovre, something '
#                           'gigantic awakens after being trapped for a thousand '
#                           'years. Destroying everything in its path, the '
#                           'creature is fast approaching the capital of Norway. '
#                           'But how do you stop something you thought only '
#                           'existed in Norwegian folklore?',
#               'popularity': 3593.992,
#               'poster_path': '/9z4jRr43JdtU66P0iy8h18OyLql.jpg',
#               'release_date': '2022-12-01',
#               'title': 'Troll',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 710},
#              {'adult': False,
#               'backdrop_path': '/Yc9q6QuWrMp9nuDm5R8ExNqbEq.jpg',
#               'genre_ids': [28, 12, 14, 878],
#               'id': 19995,
#               'original_language': 'en',
#               'original_title': 'Avatar',
#               'overview': 'In the 22nd century, a paraplegic Marine is '
#                           'dispatched to the moon Pandora on a unique mission, '
#                           'but becomes torn between following orders and '
#                           'protecting an alien civilization.',
#               'popularity': 3424.983,
#               'poster_path': '/jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg',
#               'release_date': '2009-12-15',
#               'title': 'Avatar',
#               'video': False,
#               'vote_average': 7.5,
#               'vote_count': 26995},
#              {'adult': False,
#               'backdrop_path': '/vSvogVWimBiaKx9dVCzirh3u9qS.jpg',
#               'genre_ids': [16, 14, 18],
#               'id': 555604,
#               'original_language': 'en',
#               'original_title': "Guillermo del Toro's Pinocchio",
#               'overview': "During the rise of fascism in Mussolini's Italy, a "
#                           'wooden boy brought magically to life struggles to '
#                           "live up to his father's expectations.",
#               'popularity': 3714.019,
#               'poster_path': '/vx1u0uwxdlhV2MUzj4VlcMB0N6m.jpg',
#               'release_date': '2022-11-09',
#               'title': "Guillermo del Toro's Pinocchio",
#               'video': False,
#               'vote_average': 8.5,
#               'vote_count': 767},
#              {'adult': False,
#               'backdrop_path': '/7zQJYV02yehWrQN6NjKsBorqUUS.jpg',
#               'genre_ids': [28, 18, 36],
#               'id': 724495,
#               'original_language': 'en',
#               'original_title': 'The Woman King',
#               'overview': 'The story of the Agojie, the all-female unit of '
#                           'warriors who protected the African Kingdom of '
#                           'Dahomey in the 1800s with skills and a fierceness '
#                           'unlike anything the world has ever seen, and '
#                           'General Nanisca as she trains the next generation '
#                           'of recruits and readies them for battle against an '
#                           'enemy determined to destroy their way of life.',
#               'popularity': 2183.8,
#               'poster_path': '/438QXt1E3WJWb3PqNniK0tAE5c1.jpg',
#               'release_date': '2022-09-15',
#               'title': 'The Woman King',
#               'video': False,
#               'vote_average': 7.8,
#               'vote_count': 791},
#              {'adult': False,
#               'backdrop_path': '/83IYtUhc7Vs8XYi5UYc2lUKuyMo.jpg',
#               'genre_ids': [28, 80, 53],
#               'id': 873126,
#               'original_language': 'it',
#               'original_title': 'Il mio nome è vendetta',
#               'overview': 'After old enemies kill his family, a former mafia '
#                           'enforcer and his feisty daughter flee to Milan, '
#                           'where they hide out while plotting their revenge.',
#               'popularity': 2013.102,
#               'poster_path': '/7l3war94J4tRyWUiLAGokr3ViF2.jpg',
#               'release_date': '2022-11-30',
#               'title': 'My Name Is Vendetta',
#               'video': False,
#               'vote_average': 6.8,
#               'vote_count': 196},
#              {'adult': False,
#               'backdrop_path': '/zNE4oUkZnpbCpFiJbbaX4YJOPmE.jpg',
#               'genre_ids': [28, 80],
#               'id': 1024546,
#               'original_language': 'en',
#               'original_title': 'Detective Knight: Rogue',
#               'overview': 'As Los Angeles prepares for Halloween, mask-wearing '
#                           'armed robbers critically wound detective James '
#                           'Knight’s partner in a shootout following a heist. '
#                           'With Knight in hot pursuit, the bandits flee L.A. '
#                           'for New York, where the detective’s dark past '
#                           'collides with his present case and threatens to '
#                           'tear his world apart…unless redemption can claim '
#                           'Knight first.',
#               'popularity': 1727.789,
#               'poster_path': '/2wj5iUJ2B5AQ1lFctJgUrHHsp9B.jpg',
#               'release_date': '2022-10-21',
#               'title': 'Detective Knight: Rogue',
#               'video': False,
#               'vote_average': 5.4,
#               'vote_count': 17},
#              {'adult': False,
#               'backdrop_path': '/86uhKWx1PyKfUXyu0bCyxCgcs2L.jpg',
#               'genre_ids': [53],
#               'id': 878183,
#               'original_language': 'en',
#               'original_title': 'The Independent',
#               'overview': "It's the final weeks of the most consequential "
#                           'presidential election in history. America is poised '
#                           'to elect either its first female president or its '
#                           'first viable independent candidate. Reporting '
#                           "history as it's made, an idealistic young "
#                           'journalist teams up with her idol, legendary '
#                           'journalist Nick Booker, to uncover a conspiracy '
#                           'that places the fate of the election, and the '
#                           'country, in their hands.',
#               'popularity': 1781.209,
#               'poster_path': '/jhlc1nsD8nnnGymEFaZ0twMH6M6.jpg',
#               'release_date': '2022-11-02',
#               'title': 'The Independent',
#               'video': False,
#               'vote_average': 7.2,
#               'vote_count': 27},
#              {'adult': False,
#               'backdrop_path': '/6rax7iv5yQtldc3ApEvrheJf8uw.jpg',
#               'genre_ids': [16, 35, 10751, 14],
#               'id': 751741,
#               'original_language': 'en',
#               'original_title': 'Night at the Museum: Kahmunrah Rises Again',
#               'overview': "Nick Daley is following in his father's footsteps "
#                           'as night watchman at the American Museum of Natural '
#                           'History, so he knows what happens when the sun goes '
#                           'down. But when the maniacal ruler Kahmunrah '
#                           'escapes, it is up to Nick to save the museum once '
#                           'and for all.',
#               'popularity': 2437.235,
#               'poster_path': '/mkRQn520JQD07BNP03NK3iKCaPD.jpg',
#               'release_date': '2022-12-09',
#               'title': 'Night at the Museum: Kahmunrah Rises Again',
#               'video': False,
#               'vote_average': 7.1,
#               'vote_count': 71},
#              {'adult': False,
#               'backdrop_path': '/xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg',
#               'genre_ids': [28, 12, 878],
#               'id': 505642,
#               'original_language': 'en',
#               'original_title': 'Black Panther: Wakanda Forever',
#               'overview': 'Queen Ramonda, Shuri, M’Baku, Okoye and the Dora '
#                           'Milaje fight to protect their nation from '
#                           'intervening world powers in the wake of King '
#                           'T’Challa’s death. As the Wakandans strive to '
#                           'embrace their next chapter, the heroes must band '
#                           'together with the help of War Dog Nakia and Everett '
#                           'Ross and forge a new path for the kingdom of '
#                           'Wakanda.',
#               'popularity': 1591.587,
#               'poster_path': '/ps2oKfhY6DL3alynlSqY97gHSsg.jpg',
#               'release_date': '2022-11-09',
#               'title': 'Black Panther: Wakanda Forever',
#               'video': False,
#               'vote_average': 7.5,
#               'vote_count': 1395},
#              {'adult': False,
#               'backdrop_path': '/kmzppWh7ljL6K9fXW72bPN3gKwu.jpg',
#               'genre_ids': [14, 28, 35, 80],
#               'id': 1013860,
#               'original_language': 'en',
#               'original_title': 'R.I.P.D. 2: Rise of the Damned',
#               'overview': 'When Sheriff Roy Pulsipher finds himself in the '
#                           'afterlife, he joins a special police force and '
#                           'returns to Earth to save humanity from the undead.',
#               'popularity': 1534.95,
#               'poster_path': '/g4yJTzMtOBUTAR2Qnmj8TYIcFVq.jpg',
#               'release_date': '2022-11-15',
#               'title': 'R.I.P.D. 2: Rise of the Damned',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 257},
#              {'adult': False,
#               'backdrop_path': '/2T92w8l2iTnyG9jwOmIWfM9thRV.jpg',
#               'genre_ids': [16, 10751, 12],
#               'id': 1045944,
#               'original_language': 'en',
#               'original_title': 'The Boss Baby: Christmas Bonus',
#               'overview': 'Christmas Eve takes a twisty turn when the Boss '
#                           "Baby accidentally swaps places with one of Santa's "
#                           'elves and gets stranded at the North Pole.',
#               'popularity': 1320.912,
#               'poster_path': '/iMmMxF6f2OonUrXrHKBLSYAhXly.jpg',
#               'release_date': '2022-12-06',
#               'title': 'The Boss Baby: Christmas Bonus',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 86},
#              {'adult': False,
#               'backdrop_path': '/90ZZIoWQLLEXSVm0ik3eEQBinul.jpg',
#               'genre_ids': [28, 27, 53],
#               'id': 988233,
#               'original_language': 'en',
#               'original_title': 'Hex',
#               'overview': 'Following a mysterious disappearance on a jump, a '
#                           'group of skydivers experiences paranormal '
#                           'occurrences that leave them fighting for their '
#                           'lives.',
#               'popularity': 1349.759,
#               'poster_path': '/xFJHb43ZAnnuiDztxZYsmyopweb.jpg',
#               'release_date': '2022-11-01',
#               'title': 'Hex',
#               'video': False,
#               'vote_average': 5.2,
#               'vote_count': 17},
#              {'adult': False,
#               'backdrop_path': '/sUuzl04qNIYsnwCLQpZ2RSvXA1V.jpg',
#               'genre_ids': [35, 28, 53],
#               'id': 792775,
#               'original_language': 'is',
#               'original_title': 'Leynilögga',
#               'overview': "When Bússi, Iceland's toughest cop, is forced to "
#                           'work with a new partner to solve a series of bank '
#                           'robberies, the pressure to close the case as soon '
#                           'as possible proves too much for him.',
#               'popularity': 1411.694,
#               'poster_path': '/jnWyZsaCl3Ke6u6ReSmBRO8S1rX.jpg',
#               'release_date': '2022-05-23',
#               'title': 'Cop Secret',
#               'video': False,
#               'vote_average': 6.1,
#               'vote_count': 39},
#              {'adult': False,
#               'backdrop_path': '/dsWxCsAdsocMNQFbhe39ynAOhBa.jpg',
#               'genre_ids': [80, 53],
#               'id': 1049233,
#               'original_language': 'pl',
#               'original_title': 'Plan lekcji',
#               'overview': 'After a teacher dies, his best friend — a former '
#                           'cop — takes a job at the school where he worked to '
#                           'confront the gang he thinks was responsible.',
#               'popularity': 1291.218,
#               'poster_path': '/e4nR9m6nY7HpaaeiEL1ixaYqReq.jpg',
#               'release_date': '2022-11-23',
#               'title': 'Lesson Plan',
#               'video': False,
#               'vote_average': 6.3,
#               'vote_count': 71},
#              {'adult': False,
#               'backdrop_path': '/ypFD4TJ3nLJesou76V59CnweaT0.jpg',
#               'genre_ids': [36, 18, 53, 28],
#               'id': 715931,
#               'original_language': 'en',
#               'original_title': 'Emancipation',
#               'overview': 'Inspired by the gripping true story of a man who '
#                           'would do anything for his family—and for freedom. '
#                           'When Peter, an enslaved man, risks his life to '
#                           'escape and return to his family, he embarks on a '
#                           'perilous journey of love and endurance.',
#               'popularity': 1100.861,
#               'poster_path': '/s9sUK1vAaOcxJfKzNTszrNkPhkH.jpg',
#               'release_date': '2022-12-02',
#               'title': 'Emancipation',
#               'video': False,
#               'vote_average': 8.2,
#               'vote_count': 374},
#              {'adult': False,
#               'backdrop_path': '/uEwGFGtao9YG2JolmdvtHLLVbA9.jpg',
#               'genre_ids': [99],
#               'id': 111332,
#               'original_language': 'en',
#               'original_title': 'Avatar: Creating the World of Pandora',
#               'overview': "The Making-of James Cameron's Avatar. It shows "
#                           'interesting parts of the work on the set.',
#               'popularity': 1315.738,
#               'poster_path': '/sjf3xjuofCtDhZghJRzXlTiEjJe.jpg',
#               'release_date': '2010-02-07',
#               'title': 'Avatar: Creating the World of Pandora',
#               'video': False,
#               'vote_average': 7.3,
#               'vote_count': 29},
#              {'adult': False,
#               'backdrop_path': '/5aSvzECXrtABcIh7fZYkH2K6ttC.jpg',
#               'genre_ids': [28, 53, 80],
#               'id': 972313,
#               'original_language': 'en',
#               'original_title': 'Blowback',
#               'overview': 'When a master thief is sabotaged during a bank '
#                           'heist and left for dead, he seeks revenge on his '
#                           'former crew one target at a time. Now, with the '
#                           "cops and the mob closing in, he's in the race of "
#                           'his life to reclaim an untold fortune in '
#                           'cryptocurrency from those who double-crossed him.',
#               'popularity': 1049.647,
#               'poster_path': '/fHQHC32dhom8u0OxC2hs2gYQh0M.jpg',
#               'release_date': '2022-06-17',
#               'title': 'Blowback',
#               'video': False,
#               'vote_average': 5.9,
#               'vote_count': 28},
#              {'adult': False,
#               'backdrop_path': '/vmDa8HijINCAFYKqsMz0YM3sVyE.jpg',
#               'genre_ids': [28, 80, 53],
#               'id': 747803,
#               'original_language': 'en',
#               'original_title': 'One Way',
#               'overview': 'On the run with a bag full of cash after a robbing '
#                           'his former crime boss—and a potentially fatal '
#                           'wound—Freddy slips onto a bus headed into the '
#                           'unrelenting California desert. With his life '
#                           'slipping through his fingers, Freddy is left with '
#                           'very few choices to survive.',
#               'popularity': 1006.585,
#               'poster_path': '/uQCxOziq79P3wDsRwQhhkhQyDsJ.jpg',
#               'release_date': '2022-09-02',
#               'title': 'One Way',
#               'video': False,
#               'vote_average': 6.9,
#               'vote_count': 43}],
#  'total_pages': 36364,
#  'total_results': 727277}

# %% [markdown]
# ###Get title, id, and overview for movies

# %%
# Getting one movide id
popular['results'][0]['id']
# Out:
# 436270

# %% [markdown]
# ###We can use for loop to get every movies title, id, and overview

# %%
# Get the list of movies from the results field
movies = popular["results"]

# Create an empty list to store the movie information
movie_info = []

# Iterate over the list of movies
for movie in movies:
    # Get the id, title, and overview of the current movie
    movie_title = movie["title"]
    movie_id = movie["id"]
    movie_overview = movie["overview"]
    vote_average = movie['vote_average']
    
    # Create a dictionary with the id, title, and overview of the current movie
    current_movie = {
        "title": movie_title,
        "id": movie_id,
        "overview": movie_overview,
        "vote_average": vote_average
    }
    
    # Add the movie information to the list of movie info
    movie_info.append(current_movie)

# Print the list of movie info
print(movie_info)
# Out:
# [{'title': 'Black Adam', 'id': 436270, 'overview': 'Nearly 5,000 years after he was bestowed with the almighty powers of the Egyptian gods—and imprisoned just as quickly—Black Adam is freed from his earthly tomb, ready to unleash his unique form of justice on the modern world.', 'vote_average': 7.2}, {'title': 'Avatar: The Way of Water', 'id': 76600, 'overview': 'Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.', 'vote_average': 8.1}, {'title': 'Troll', 'id': 736526, 'overview': 'Deep inside the mountain of Dovre, something gigantic awakens after being trapped for a thousand years. Destroying everything in its path, the creature is fast approaching the capital of Norway. But how do you stop something you thought only existed in Norwegian folklore?', 'vote_average': 6.7}, {'title': 'Avatar', 'id': 19995, 'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.', 'vote_average': 7.5}, {'title': "Guillermo del Toro's Pinocchio", 'id': 555604, 'overview': "During the rise of fascism in Mussolini's Italy, a wooden boy brought magically to life struggles to live up to his father's expectations.", 'vote_average': 8.5}, {'title': 'The Woman King', 'id': 724495, 'overview': 'The story of the Agojie, the all-female unit of warriors who protected the African Kingdom of Dahomey in the 1800s with skills and a fierceness unlike anything the world has ever seen, and General Nanisca as she trains the next generation of recruits and readies them for battle against an enemy determined to destroy their way of life.', 'vote_average': 7.8}, {'title': 'My Name Is Vendetta', 'id': 873126, 'overview': 'After old enemies kill his family, a former mafia enforcer and his feisty daughter flee to Milan, where they hide out while plotting their revenge.', 'vote_average': 6.8}, {'title': 'Detective Knight: Rogue', 'id': 1024546, 'overview': 'As Los Angeles prepares for Halloween, mask-wearing armed robbers critically wound detective James Knight’s partner in a shootout following a heist. With Knight in hot pursuit, the bandits flee L.A. for New York, where the detective’s dark past collides with his present case and threatens to tear his world apart…unless redemption can claim Knight first.', 'vote_average': 5.4}, {'title': 'The Independent', 'id': 878183, 'overview': "It's the final weeks of the most consequential presidential election in history. America is poised to elect either its first female president or its first viable independent candidate. Reporting history as it's made, an idealistic young journalist teams up with her idol, legendary journalist Nick Booker, to uncover a conspiracy that places the fate of the election, and the country, in their hands.", 'vote_average': 7.2}, {'title': 'Night at the Museum: Kahmunrah Rises Again', 'id': 751741, 'overview': "Nick Daley is following in his father's footsteps as night watchman at the American Museum of Natural History, so he knows what happens when the sun goes down. But when the maniacal ruler Kahmunrah escapes, it is up to Nick to save the museum once and for all.", 'vote_average': 7.1}, {'title': 'Black Panther: Wakanda Forever', 'id': 505642, 'overview': 'Queen Ramonda, Shuri, M’Baku, Okoye and the Dora Milaje fight to protect their nation from intervening world powers in the wake of King T’Challa’s death. As the Wakandans strive to embrace their next chapter, the heroes must band together with the help of War Dog Nakia and Everett Ross and forge a new path for the kingdom of Wakanda.', 'vote_average': 7.5}, {'title': 'R.I.P.D. 2: Rise of the Damned', 'id': 1013860, 'overview': 'When Sheriff Roy Pulsipher finds himself in the afterlife, he joins a ...

# %% [markdown]
# ###Lets "pretty-print” this Python data structure into a more digestiable form

# %%
pprint(movie_info)
# Out:
# [{'id': 436270,
#   'overview': 'Nearly 5,000 years after he was bestowed with the almighty '
#               'powers of the Egyptian gods—and imprisoned just as '
#               'quickly—Black Adam is freed from his earthly tomb, ready to '
#               'unleash his unique form of justice on the modern world.',
#   'title': 'Black Adam',
#   'vote_average': 7.2},
#  {'id': 76600,
#   'overview': 'Set more than a decade after the events of the first film, '
#               'learn the story of the Sully family (Jake, Neytiri, and their '
#               'kids), the trouble that follows them, the lengths they go to '
#               'keep each other safe, the battles they fight to stay alive, and '
#               'the tragedies they endure.',
#   'title': 'Avatar: The Way of Water',
#   'vote_average': 8.1},
#  {'id': 736526,
#   'overview': 'Deep inside the mountain of Dovre, something gigantic awakens '
#               'after being trapped for a thousand years. Destroying everything '
#               'in its path, the creature is fast approaching the capital of '
#               'Norway. But how do you stop something you thought only existed '
#               'in Norwegian folklore?',
#   'title': 'Troll',
#   'vote_average': 6.7},
#  {'id': 19995,
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the '
#               'moon Pandora on a unique mission, but becomes torn between '
#               'following orders and protecting an alien civilization.',
#   'title': 'Avatar',
#   'vote_average': 7.5},
#  {'id': 555604,
#   'overview': "During the rise of fascism in Mussolini's Italy, a wooden boy "
#               "brought magically to life struggles to live up to his father's "
#               'expectations.',
#   'title': "Guillermo del Toro's Pinocchio",
#   'vote_average': 8.5},
#  {'id': 724495,
#   'overview': 'The story of the Agojie, the all-female unit of warriors who '
#               'protected the African Kingdom of Dahomey in the 1800s with '
#               'skills and a fierceness unlike anything the world has ever '
#               'seen, and General Nanisca as she trains the next generation of '
#               'recruits and readies them for battle against an enemy '
#               'determined to destroy their way of life.',
#   'title': 'The Woman King',
#   'vote_average': 7.8},
#  {'id': 873126,
#   'overview': 'After old enemies kill his family, a former mafia enforcer and '
#               'his feisty daughter flee to Milan, where they hide out while '
#               'plotting their revenge.',
#   'title': 'My Name Is Vendetta',
#   'vote_average': 6.8},
#  {'id': 1024546,
#   'overview': 'As Los Angeles prepares for Halloween, mask-wearing armed '
#               'robbers critically wound detective James Knight’s partner in a '
#               'shootout following a heist. With Knight in hot pursuit, the '
#               'bandits flee L.A. for New York, where the detective’s dark past '
#               'collides with his present case and threatens to tear his world '
#               'apart…unless redemption can claim Knight first.',
#   'title': 'Detective Knight: Rogue',
#   'vote_average': 5.4},
#  {'id': 878183,
#   'overview': "It's the final weeks of the most consequential presidential "
#               'election in history. America is poised to elect either its '
#               'first female president or its first viable independent '
#               "candidate. Reporting history as it's made, an idealistic young "
#               'journalist teams up with her idol, legendary journalist Nick '
#               'Booker, to uncover a conspiracy that places the fate of the '
#               'election, and the country, in their hands.',
#   'title': 'The Independent',
#   'vote_average': 7.2},
#  {'id': 751741,
#   'overview': "Nick Daley is following in his father's footsteps as night "
#               'watchman at the American Museum of Natural History, so he knows '
#               'what happens when the sun goes down. But when the maniacal '
#               'ruler Kahmunrah escapes, it is up to Nick to save the museum '
#               'once and for all.',
#   'title': 'Night at the Museum: Kahmunrah Rises Again',
#   'vote_average': 7.1},
#  {'id': 505642,
#   'overview': 'Queen Ramonda, Shuri, M’Baku, Okoye and the Dora Milaje fight '
#               'to protect their nation from intervening world powers in the '
#               'wake of King T’Challa’s death. As the Wakandans strive to '
#               'embrace their next chapter, the heroes must band together with '
#               'the help of War Dog Nakia and Everett Ross and forge a new path '
#               'for the kingdom of Wakanda.',
#   'title': 'Black Panther: Wakanda Forever',
#   'vote_average': 7.5},
#  {'id': 1013860,
#   'overview': 'When Sheriff Roy Pulsipher finds himself in the afterlife, he '
#               'joins a special police force and returns to Earth to save '
#               'humanity from the undead.',
#   'title': 'R.I.P.D. 2: Rise of the Damned',
#   'vote_average': 6.7},
#  {'id': 1045944,
#   'overview': 'Christmas Eve takes a twisty turn when the Boss Baby '
#               "accidentally swaps places with one of Santa's elves and gets "
#               'stranded at the North Pole.',
#   'title': 'The Boss Baby: Christmas Bonus',
#   'vote_average': 6.7},
#  {'id': 988233,
#   'overview': 'Following a mysterious disappearance on a jump, a group of '
#               'skydivers experiences paranormal occurrences that leave them '
#               'fighting for their lives.',
#   'title': 'Hex',
#   'vote_average': 5.2},
#  {'id': 792775,
#   'overview': "When Bússi, Iceland's toughest cop, is forced to work with a "
#               'new partner to solve a series of bank robberies, the pressure '
#               'to close the case as soon as possible proves too much for him.',
#   'title': 'Cop Secret',
#   'vote_average': 6.1},
#  {'id': 1049233,
#   'overview': 'After a teacher dies, his best friend — a former cop — takes a '
#               'job at the school where he worked to confront the gang he '
#               'thinks was responsible.',
#   'title': 'Lesson Plan',
#   'vote_average': 6.3},
#  {'id': 715931,
#   'overview': 'Inspired by the gripping true story of a man who would do '
#               'anything for his family—and for freedom. When Peter, an '
#               'enslaved man, risks his life to escape and return to his '
#               'family, he embarks on a perilous journey of love and endurance.',
#   'title': 'Emancipation',
#   'vote_average': 8.2},
#  {'id': 111332,
#   'overview': "The Making-of James Cameron's Avatar. It shows interesting "
#               'parts of the work on the set.',
#   'title': 'Avatar: Creating the World of Pandora',
#   'vote_average': 7.3},
#  {'id': 972313,
#   'overview': 'When a master thief is sabotaged during a bank heist and left '
#               'for dead, he seeks revenge on his former crew one target at a '
#               "time. Now, with the cops and the mob closing in, he's in the "
#               'race of his life to reclaim an untold fortune in cryptocurrency '
#               'from those who double-crossed him.',
#   'title': 'Blowback',
#   'vote_average': 5.9},
#  {'id': 747803,
#   'overview': 'On the run with a bag full of cash after a robbing his former '
#               'crime boss—and a potentially fatal wound—Freddy slips onto a '
#               'bus headed into the unrelenting California desert. With his '
#               'life slipping through his fingers, Freddy is left with very few '
#               'choices to survive.',
#   'title': 'One Way',
#   'vote_average': 6.9}]

# %%
import pandas as pd
movie_df = pd.DataFrame(movie_info)
movie_df.columns = ["title","id", "overview", 'vote_average']
movie_df
# Out:
#                                          title       id  \
# 0                                   Black Adam   436270
# 1                     Avatar: The Way of Water    76600
# 2                                        Troll   736526
# 3                                       Avatar    19995
# 4               Guillermo del Toro's Pinocchio   555604
# 5                               The Woman King   724495
# 6                          My Name Is Vendetta   873126
# 7                      Detective Knight: Rogue  1024546
# 8                              The Independent   878183
# 9   Night at the Museum: Kahmunrah Rises Again   751741
# 10              Black Panther: Wakanda Forever   505642
# 11              R.I.P.D. 2: Rise of the Damned  1013860
# 12              The Boss Baby: Christmas Bonus  1045944
# 13                                         Hex   988233
# 14                                  Cop Secret   792775
# 15                                 Lesson Plan  1049233
# 16                                Emancipation   715931
# 17       Avatar: Creating the World of Pandora   111332
# 18                                    Blowback   972313
# 19                                     One Way   747803
#
#                                              overview  vote_average
# 0   Nearly 5,000 years after he was bestowed with ...           7.2
# 1   Set more than a decade after the events of the...           8.1
# 2   Deep inside the mountain of Dovre, something g...           6.7
# 3   In the 22nd century, a paraplegic Marine is di...           7.5
# 4   During the rise of fascism in Mussolini's Ital...           8.5
# 5   The story of the Agojie, the all-female unit o...           7.8
# 6   After old enemies kill his family, a former ma...           6.8
# 7   As Los Angeles prepares for Halloween, mask-we...           5.4
# 8   It's the final weeks of the most consequential...           7.2
# 9   Nick Daley is following in his father's footst...           7.1
# 10  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...           7.5
# 11  When Sheriff Roy Pulsipher finds himself in th...           6.7
# 12  Christmas Eve takes a twisty turn when the Bos...           6.7
# 13  Following a mysterious disappearance on a jump...           5.2
# 14  When Bússi, Iceland's toughest cop, is forced ...           6.1
# 15  After a teacher dies, his best friend — a form...           6.3
# 16  Inspired by the gripping true story of a man w...           8.2
# 17  The Making-of James Cameron's Avatar. It shows...           7.3
# 18  When a master thief is sabotaged during a bank...           5.9
# 19  On the run with a bag full of cash after a rob...           6.9

# %% [markdown]
# ###Get movie trailers based off of movie ids

# %%
movie_id = input("Please input the id of the movie you are interested in")
print(f"You chose the id {movie_id}")
# Out:
# Please input the id of the movie you are interested in725201
# You chose the id 725201

# %%
base_url = f"https://api.themoviedb.org/3/movie/{movie_id}/videos?api_key=e93793ba5e52b020648e1f1544b82e55&language=en-US&page=1"
headers = {'Authorization': token, 'User-Agent': 'TMDB App'}
response = requests.get(base_url, headers=headers)
trailers = response.json()

# %% [markdown]
# ###Here is a list of Trailers for the movie of your choosing

# %%
pprint(trailers)
# Out:
# {'id': 725201,
#  'results': [{'id': '62e816351ad93b0059a2401b',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': '1QgbJ929kyw',
#               'name': 'Behind the FX of The Gray Man with Ryan Gosling & the '
#                       'Russo Brothers',
#               'official': True,
#               'published_at': '2022-07-31T13:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Behind the Scenes'},
#              {'id': '62e8160afdf8b70059be5a73',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'vgLxE2qauXs',
#               'name': 'Behind The Scenes Of The Gray Man’s Epic Action & '
#                       'Stunts',
#               'official': True,
#               'published_at': '2022-07-29T17:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Behind the Scenes'},
#              {'id': '62e81682fc5f06006107040a',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'UyhIqvLvGrM',
#               'name': 'Easter Eggs You Missed in The Gray Man ft. The Russo '
#                       'Brothers',
#               'official': True,
#               'published_at': '2022-07-28T13:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Featurette'},
#              {'id': '62e816633081310058a7ef91',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'lsQT2wSVYxM',
#               'name': "We Tested Ryan Gosling's Knowledge of Spy Gadgets",
#               'official': True,
#               'published_at': '2022-07-27T17:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Featurette'},
#              {'id': '62e816f51bf266005da3ea3a',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'KbHwbv_0k4A',
#               'name': 'Plane Fight Scene',
#               'official': True,
#               'published_at': '2022-07-23T13:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Clip'},
#              {'id': '62e8174c1c09fb006001425f',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'pDm_hdEDF8I',
#               'name': 'Ryan Gosling Loves Step Brothers and Eva Mendes',
#               'official': True,
#               'published_at': '2022-07-19T13:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Featurette'},
#              {'id': '62e817751c635b0058c6186e',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'UaFigz3pNwY',
#               'name': 'Inside the Russo Brothers’ Office (ft. Exclusive Marvel '
#                       'Easter Eggs)',
#               'official': True,
#               'published_at': '2022-07-18T15:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Featurette'},
#              {'id': '62d4b779e6d3cc005095a923',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'fBpdF_Vrh40',
#               'name': 'Exclusive Featurette | Behind the Action',
#               'official': True,
#               'published_at': '2022-07-15T16:00:00.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Behind the Scenes'},
#              {'id': '62cd0c054a4bfc0055ed0d17',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'D346arxIYBk',
#               'name': 'Dhanush Fights Ryan Gosling and Ana De Armas',
#               'official': True,
#               'published_at': '2022-07-12T03:22:53.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Clip'},
#              {'id': '629f87d1d2147c117cb2c761',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': '6q93pzTw2rY',
#               'name': 'Gosling vs. Evans Exclusive Clip',
#               'official': True,
#               'published_at': '2022-06-07T17:00:02.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Clip'},
#              {'id': '62bbd8422e2b2c031d256860',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'OryyR6ad2rQ',
#               'name': 'Official Malayalam Trailer [English Subtitled]',
#               'official': True,
#               'published_at': '2022-05-25T15:30:10.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Trailer'},
#              {'id': '62bbd83d12aabc061cb21940',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'Fnsb3VuBms8',
#               'name': 'Official Telugu Trailer [English Subtitled]',
#               'official': True,
#               'published_at': '2022-05-25T14:00:07.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Trailer'},
#              {'id': '62bbd836a1a9ba009227bbbb',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'pfLY_2f44pc',
#               'name': 'Official Tamil Trailer [English Subtitled]',
#               'official': True,
#               'published_at': '2022-05-25T11:30:10.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Trailer'},
#              {'id': '62954fd376eecf75b0ad141a',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': '3TPv-NQObhI',
#               'name': 'The Russo Brothers Break Down Their Epic Movie Trailer',
#               'official': True,
#               'published_at': '2022-05-24T14:00:05.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Featurette'},
#              {'id': '62bbd82f23bcf4008c7bf8c1',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'POLixFkmK9A',
#               'name': 'Official Hindi Trailer [English Subtitled]',
#               'official': True,
#               'published_at': '2022-05-24T13:30:37.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Trailer'},
#              {'id': '628ce4f00b73160050c8b506',
#               'iso_3166_1': 'US',
#               'iso_639_1': 'en',
#               'key': 'BmllggGO4pM',
#               'name': 'Official Trailer',
#               'official': True,
#               'published_at': '2022-05-24T13:30:18.000Z',
#               'site': 'YouTube',
#               'size': 1080,
#               'type': 'Trailer'}]}

# %% [markdown]
# ###Here you will find the first trailer to the movie of your chossing

# %%
pprint(trailers['results'][0])
# Out:
# {'id': '637da56501757f00dfe33e26',
#  'iso_3166_1': 'US',
#  'iso_639_1': 'en',
#  'key': '7wlWhevF2y4',
#  'name': 'First 9 Minutes',
#  'official': True,
#  'published_at': '2022-11-22T19:58:55.000Z',
#  'site': 'YouTube',
#  'size': 1080,
#  'type': 'Clip'}

# %%
key = trailers['results'][0]['key']
print(key)
# Out:
# 7wlWhevF2y4

# %%
key
# Out:
# 'Dr3fpmRnokc'

# %%
print(f"Use this link to access the youtube trailer https://www.youtube.com/watch?v={key}")
# Out:
# Use this link to access the youtube trailer https://www.youtube.com/watch?v=Dr3fpmRnokc

# %% [markdown]
# ###Where can I stream the movie?

# %%
base_url = f'https://api.themoviedb.org/3/movie/{movie_id}/watch/providers?api_key=e93793ba5e52b020648e1f1544b82e55&language=en-US&page=1'
headers = {'Authorization': token, 'User-Agent': 'TMDB App'}
response = requests.get(base_url, headers=headers)
providers = response.json()

# %%
pprint(providers)

# %% [markdown]
# ###Based off of the id get a list of other movie recommendations

# %%
base_url = f'https://api.themoviedb.org/3/movie/{movie_id}/recommendations?api_key=e93793ba5e52b020648e1f1544b82e55&language=en-US&page=1'
headers = {'Authorization': token, 'User-Agent': 'TMDB App'}
response = requests.get(base_url, headers=headers)
recom = response.json()

# %%
pprint(recom)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/5PnypKiSj2efSPqThNjTXz8jwOg.jpg',
#               'genre_ids': [14, 28],
#               'id': 759175,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'The Princess',
#               'overview': 'A beautiful, strong-willed young royal refuses to '
#                           'wed the cruel sociopath to whom she is betrothed '
#                           'and is kidnapped and locked in a remote tower of '
#                           'her father’s castle. With her scorned, vindictive '
#                           'suitor intent on taking her father’s throne, the '
#                           'princess must protect her family and save the '
#                           'kingdom.',
#               'popularity': 126.228,
#               'poster_path': '/9pCoqX24a6rE981fY1O3PmhiwrB.jpg',
#               'release_date': '2022-06-16',
#               'title': 'The Princess',
#               'video': False,
#               'vote_average': 6.92,
#               'vote_count': 600},
#              {'adult': False,
#               'backdrop_path': '/1h0NFa8irKpyQEvGlH87Ej5yPAH.jpg',
#               'genre_ids': [18, 28, 12],
#               'id': 978436,
#               'media_type': 'movie',
#               'original_language': 'tr',
#               'original_title': 'Adanis: Kutsal Kavga',
#               'overview': '',
#               'popularity': 69.66,
#               'poster_path': '/1G5mt3uGUW5OWUcxcBUtHm5Zdd9.jpg',
#               'release_date': '2022-03-11',
#               'title': 'Adanis: Kutsal Kavga',
#               'video': False,
#               'vote_average': 5.167,
#               'vote_count': 15},
#              {'adult': False,
#               'backdrop_path': '/jauI01vUIkPA0xVsamGj0Gs1nNL.jpg',
#               'genre_ids': [12, 28, 878],
#               'id': 507086,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Jurassic World Dominion',
#               'overview': 'Four years after the destruction of Isla Nublar, '
#                           'Biosyn operatives attempt to track down Maisie '
#                           'Lockwood, while Dr Ellie Sattler investigates a '
#                           'genetically engineered swarm of giant insects.',
#               'popularity': 406.03,
#               'poster_path': '/kAVRgw7GgK1CfYEJq8ME6EvRIgU.jpg',
#               'release_date': '2022-06-01',
#               'title': 'Jurassic World Dominion',
#               'video': False,
#               'vote_average': 6.966,
#               'vote_count': 4004},
#              {'adult': False,
#               'backdrop_path': '/7ZO9yoEU2fAHKhmJWfAc2QIPWJg.jpg',
#               'genre_ids': [53, 28, 878],
#               'id': 766507,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Prey',
#               'overview': 'When danger threatens her camp, the fierce and '
#                           'highly skilled Comanche warrior Naru sets out to '
#                           'protect her people. But the prey she stalks turns '
#                           'out to be a highly evolved alien predator with a '
#                           'technically advanced arsenal.',
#               'popularity': 371.929,
#               'poster_path': '/ujr5pztc1oitbe7ViMUOilFaJ7s.jpg',
#               'release_date': '2022-08-02',
#               'title': 'Prey',
#               'video': False,
#               'vote_average': 7.853,
#               'vote_count': 4788},
#              {'adult': False,
#               'backdrop_path': '/iOFBH9KtjKMntbP2kheeOpMQTcC.jpg',
#               'genre_ids': [28, 35],
#               'id': 667739,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'The Man from Toronto',
#               'overview': 'In a case of mistaken identity, the world’s '
#                           'deadliest assassin, known as the Man from Toronto, '
#                           'and a New York City screw-up are forced to team up '
#                           'after being confused for each other at a rental '
#                           'cabin.',
#               'popularity': 99.455,
#               'poster_path': '/uTCfTibqtk4f90cC59bLPMOmsfc.jpg',
#               'release_date': '2022-06-24',
#               'title': 'The Man from Toronto',
#               'video': False,
#               'vote_average': 6.574,
#               'vote_count': 904},
#              {'adult': False,
#               'backdrop_path': '/jsoz1HlxczSuTx0mDl2h0lxy36l.jpg',
#               'genre_ids': [14, 28, 35],
#               'id': 616037,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Thor: Love and Thunder',
#               'overview': 'After his retirement is interrupted by Gorr the God '
#                           'Butcher, a galactic killer who seeks the extinction '
#                           'of the gods, Thor Odinson enlists the help of King '
#                           'Valkyrie, Korg, and ex-girlfriend Jane Foster, who '
#                           'now wields Mjolnir as the Mighty Thor. Together '
#                           'they embark upon a harrowing cosmic adventure to '
#                           'uncover the mystery of the God Butcher’s vengeance '
#                           'and stop him before it’s too late.',
#               'popularity': 420.392,
#               'poster_path': '/pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg',
#               'release_date': '2022-07-06',
#               'title': 'Thor: Love and Thunder',
#               'video': False,
#               'vote_average': 6.689,
#               'vote_count': 4944},
#              {'adult': False,
#               'backdrop_path': '/l99dylTOAMkwKSr54X5ytiEtnLA.jpg',
#               'genre_ids': [14, 12, 28],
#               'id': 919355,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Dragon Knight',
#               'overview': 'Many years after the war has been lost, and all the '
#                           'dragons slain, a lone knight travels the lands of '
#                           'Agonos seeking to raise an army against the demon '
#                           "lord Abaddon. When a healer's vision reveals that "
#                           'one dragon still lives, and together with an eager '
#                           'young squire, the knight sets off in search of the '
#                           'fabled creature. As the armies of Abaddon descend '
#                           'on the human kingdoms, the dragon is their last '
#                           'hope of fending off the horde, before it lays waste '
#                           'to the lands of men. But does the creature even '
#                           'exist? And if it does, will it fight for them once '
#                           'more?',
#               'popularity': 153.327,
#               'poster_path': '/zkGFADykBtfPfTv7YJooxTH52ph.jpg',
#               'release_date': '2022-03-21',
#               'title': 'Dragon Knight',
#               'video': False,
#               'vote_average': 7.125,
#               'vote_count': 32},
#              {'adult': False,
#               'backdrop_path': '/yjZM4QrgA7PqX18Es6DxvJQH3ba.jpg',
#               'genre_ids': [28, 14, 27, 35],
#               'id': 755566,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Day Shift',
#               'overview': 'An LA vampire hunter has a week to come up with the '
#                           "cash to pay for his kid's tuition and braces. "
#                           'Trying to make a living these days just might kill '
#                           'him.',
#               'popularity': 157.733,
#               'poster_path': '/bI7lGR5HuYlENlp11brKUAaPHuO.jpg',
#               'release_date': '2022-08-10',
#               'title': 'Day Shift',
#               'video': False,
#               'vote_average': 6.953,
#               'vote_count': 1353},
#              {'adult': False,
#               'backdrop_path': '/wUwizGzbTk5CTiKBnE4Pq1MONwD.jpg',
#               'genre_ids': [16, 12, 10751, 14],
#               'id': 560057,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'The Sea Beast',
#               'overview': 'The life of a legendary sea monster hunter is '
#                           'turned upside down when a young girl stows away on '
#                           'his ship.',
#               'popularity': 112.085,
#               'poster_path': '/9Zfv4Ap1e8eKOYnZPtYaWhLkk0d.jpg',
#               'release_date': '2022-06-24',
#               'title': 'The Sea Beast',
#               'video': False,
#               'vote_average': 7.602,
#               'vote_count': 904},
#              {'adult': False,
#               'backdrop_path': '/AfvIjhDu9p64jKcmohS4hsPG95Q.jpg',
#               'genre_ids': [27, 53],
#               'id': 756999,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'The Black Phone',
#               'overview': 'Finney Blake, a shy but clever 13-year-old boy, is '
#                           'abducted by a sadistic killer and trapped in a '
#                           'soundproof basement where screaming is of little '
#                           'use. When a disconnected phone on the wall begins '
#                           'to ring, Finney discovers that he can hear the '
#                           'voices of the killer’s previous victims. And they '
#                           'are dead set on making sure that what happened to '
#                           'them doesn’t happen to Finney.',
#               'popularity': 203.399,
#               'poster_path': '/lr11mCT85T1JanlgjMuhs9nMht4.jpg',
#               'release_date': '2022-06-22',
#               'title': 'The Black Phone',
#               'video': False,
#               'vote_average': 7.844,
#               'vote_count': 3227},
#              {'adult': False,
#               'backdrop_path': '/AaV1YIdWKnjAIAOe8UUKBFm327v.jpg',
#               'genre_ids': [28, 18],
#               'id': 361743,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Top Gun: Maverick',
#               'overview': 'After more than thirty years of service as one of '
#                           'the Navy’s top aviators, and dodging the '
#                           'advancement in rank that would ground him, Pete '
#                           '“Maverick” Mitchell finds himself training a '
#                           'detachment of TOP GUN graduates for a specialized '
#                           'mission the likes of which no living pilot has ever '
#                           'seen.',
#               'popularity': 439.29,
#               'poster_path': '/62HCnUTziyWcpDaBO2i1DX17ljH.jpg',
#               'release_date': '2022-05-24',
#               'title': 'Top Gun: Maverick',
#               'video': False,
#               'vote_average': 8.345,
#               'vote_count': 5069},
#              {'adult': False,
#               'backdrop_path': '/bHTAaLCXnMTThs57mAbptjmOLX2.jpg',
#               'genre_ids': [35, 18],
#               'id': 838330,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Not Okay',
#               'overview': 'An ambitious young woman, desperate for followers '
#                           'and fame, fakes a trip to Paris to up her social '
#                           'media presence. When a terrifying incident takes '
#                           'place in the real world and becomes part of her '
#                           'imaginary trip, her white lie becomes a moral '
#                           'quandary that offers her all the attention she’s '
#                           'wanted.',
#               'popularity': 28.565,
#               'poster_path': '/x1q3FkqFHBkMeKnHiS6GYgdLvUs.jpg',
#               'release_date': '2022-07-29',
#               'title': 'Not Okay',
#               'video': False,
#               'vote_average': 6.428,
#               'vote_count': 307},
#              {'adult': False,
#               'backdrop_path': '/ufagam4FwlIcgPqJlr21EshNkNd.jpg',
#               'genre_ids': [53, 27, 18],
#               'id': 629015,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Shut In',
#               'overview': 'A young single mother is held captive along with '
#                           'her two children by a violent ex and must plot '
#                           'their escape before it’s too late.',
#               'popularity': 56.663,
#               'poster_path': '/b5ug4LyLQFeR6azAJyIPBQz5ur9.jpg',
#               'release_date': '2022-03-24',
#               'title': 'Shut In',
#               'video': False,
#               'vote_average': 7.093,
#               'vote_count': 258},
#              {'adult': False,
#               'backdrop_path': '/oE0J0zaLjJZkecx2seNH90YeSmk.jpg',
#               'genre_ids': [10749, 18, 35],
#               'id': 820912,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Persuasion',
#               'overview': 'Living with her snobby family on the brink of '
#                           'bankruptcy, Anne Elliot is an unconforming woman '
#                           'with modern sensibilities. When Frederick Wentworth '
#                           '- the dashing one she once sent away - crashes back '
#                           'into her life, Anne must choose between putting the '
#                           'past behind her or listening to her heart when it '
#                           'comes to second chances.',
#               'popularity': 15.038,
#               'poster_path': '/s99WrKSEVR4RVvwm5Zn2cqrHTMM.jpg',
#               'release_date': '2022-07-01',
#               'title': 'Persuasion',
#               'video': False,
#               'vote_average': 5.938,
#               'vote_count': 393},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [16],
#               'id': 1014444,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Candlelight',
#               'overview': 'Two candles meet and fall in love, but discover '
#                           'that when they touch, the heat of their combined '
#                           'flames causes them to rapidly melt. Now they both '
#                           'must choose to live apart, or make the ultimate '
#                           'sacrifice for love.',
#               'popularity': 0.6,
#               'poster_path': '/eJJHO64SDLfHLMeLFiKD3okaepX.jpg',
#               'release_date': '2022-07-10',
#               'title': 'Candlelight',
#               'video': False,
#               'vote_average': 10.0,
#               'vote_count': 1},
#              {'adult': False,
#               'backdrop_path': '/hwUxHPkuUleJeoick4uZsrKDXxF.jpg',
#               'genre_ids': [16, 28, 12, 10751, 878],
#               'id': 718789,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Lightyear',
#               'overview': 'Legendary Space Ranger Buzz Lightyear embarks on an '
#                           'intergalactic adventure alongside a group of '
#                           'ambitious recruits and his robot companion Sox.',
#               'popularity': 162.007,
#               'poster_path': '/ox4goZd956BxqJH6iLwhWPL9ct4.jpg',
#               'release_date': '2022-06-15',
#               'title': 'Lightyear',
#               'video': False,
#               'vote_average': 7.191,
#               'vote_count': 2445},
#              {'adult': False,
#               'backdrop_path': '/bn3fAIckhOFEnrIZNCSbgHXRHLY.jpg',
#               'genre_ids': [16, 35, 10751],
#               'id': 438148,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Minions: The Rise of Gru',
#               'overview': 'A fanboy of a supervillain supergroup known as the '
#                           'Vicious 6, Gru hatches a plan to become evil enough '
#                           'to join them, with the backup of his followers, the '
#                           'Minions.',
#               'popularity': 319.663,
#               'poster_path': '/wKiOkZTN9lUUUNZLmtnwubZYONg.jpg',
#               'release_date': '2022-06-29',
#               'title': 'Minions: The Rise of Gru',
#               'video': False,
#               'vote_average': 7.518,
#               'vote_count': 2402},
#              {'adult': False,
#               'backdrop_path': '/td20oGEd3IrDQYsfASJ6p2X1D0a.jpg',
#               'genre_ids': [35],
#               'id': 65522,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'They Still Call Me Bruce',
#               'overview': 'Bruce Won arrives in America in search of an '
#                           'American G.I. who saved his life in the Korean War. '
#                           'He meets an orphan boy and together they land '
#                           'themselves in a string of outrageous situations. '
#                           'This high-strung farce culminates when a case of '
#                           'mistaken identity leads a gang of thugs to think '
#                           'Bruce is a karate master. They arrange a '
#                           'nationally-televised match which pits our hero '
#                           'against a monstrous brute, and Bruce is beaten to a '
#                           'bloody pulp...',
#               'popularity': 1.634,
#               'poster_path': '/8mHLWs4bGzYNc4qUH2utMbm4NtY.jpg',
#               'release_date': '1987-05-01',
#               'title': 'They Still Call Me Bruce',
#               'video': False,
#               'vote_average': 5.0,
#               'vote_count': 5},
#              {'adult': False,
#               'backdrop_path': '/h6XfgbzQEV4sitsIVY63pawLI0s.jpg',
#               'genre_ids': [35, 27, 10752],
#               'id': 613093,
#               'media_type': 'movie',
#               'original_language': 'es',
#               'original_title': 'Malnazidos',
#               'overview': 'During the Spanish Civil War, sworn enemies must '
#                           'work together when they encounter flesh-eating '
#                           'zombies created in a Nazi experiment.',
#               'popularity': 58.484,
#               'poster_path': '/avokvOwhjVR9GgISsSSgb2A343G.jpg',
#               'release_date': '2020-10-08',
#               'title': 'Valley of the Dead',
#               'video': False,
#               'vote_average': 6.247,
#               'vote_count': 225},
#              {'adult': False,
#               'backdrop_path': '/y2Ca1neKke2mGPMaHzlCNDVZqsK.jpg',
#               'genre_ids': [28, 35, 53],
#               'id': 718930,
#               'media_type': 'movie',
#               'original_language': 'en',
#               'original_title': 'Bullet Train',
#               'overview': 'Unlucky assassin Ladybug is determined to do his '
#                           'job peacefully after one too many gigs gone off the '
#                           'rails. Fate, however, may have other plans, as '
#                           "Ladybug's latest mission puts him on a collision "
#                           'course with lethal adversaries from around the '
#                           'globe—all with connected, yet conflicting, '
#                           "objectives—on the world's fastest train.",
#               'popularity': 394.522,
#               'poster_path': '/tVxDe01Zy3kZqaZRNiXFGDICdZk.jpg',
#               'release_date': '2022-07-03',
#               'title': 'Bullet Train',
#               'video': False,
#               'vote_average': 7.517,
#               'vote_count': 2722},
#              {'adult': False,
#               'backdrop_path': '/nyl5ERVPNMElUICsTmY98zZ5iqp.jpg',
#               'genre_ids': [35, 10749],
#               'id': 994006,
#               'media_type': 'movie',
#               'original_language': 'tl',
#               'original_title': 'The Entitled',
#               'overview': 'Suddenly catapulted into high society, a young '
#                           'woman who lacks a bit of finesse tries to integrate '
#                           'into her new surroundings.',
#               'popularity': 2.026,
#               'poster_path': '/plv85l002BHwPq7zvjceGt4h3nz.jpg',
#               'release_date': '2022-07-29',
#               'title': 'The Entitled',
#               'video': False,
#               'vote_average': 4.7,
#               'vote_count': 10}],
#  'total_pages': 2,
#  'total_results': 40}

# %%
# Get the list of movies from the results field
movies = recom["results"]

# Create an empty list to store the movie information
recommen = []

# Iterate over the list of movies
for movie in movies:
    # Get the id, title, and overview of the current movie
    movie_title = movie["title"]
    movie_id = movie["id"]
    movie_overview = movie["overview"]
    vote_average = movie['vote_average']
    
    # Create a dictionary with the id, title, and overview of the current movie
    current_movie = {
        "title": movie_title,
        "id": movie_id,
        "overview": movie_overview,
        "vote_average": vote_average
    }
    
    # Add the movie information to the list of movie info
    recommen.append(current_movie)

# Print the list of movie info
print(recommen)
# Out:
# [{'title': 'The Princess', 'id': 759175, 'overview': 'A beautiful, strong-willed young royal refuses to wed the cruel sociopath to whom she is betrothed and is kidnapped and locked in a remote tower of her father’s castle. With her scorned, vindictive suitor intent on taking her father’s throne, the princess must protect her family and save the kingdom.', 'vote_average': 6.92}, {'title': 'Adanis: Kutsal Kavga', 'id': 978436, 'overview': '', 'vote_average': 5.167}, {'title': 'Jurassic World Dominion', 'id': 507086, 'overview': 'Four years after the destruction of Isla Nublar, Biosyn operatives attempt to track down Maisie Lockwood, while Dr Ellie Sattler investigates a genetically engineered swarm of giant insects.', 'vote_average': 6.966}, {'title': 'Prey', 'id': 766507, 'overview': 'When danger threatens her camp, the fierce and highly skilled Comanche warrior Naru sets out to protect her people. But the prey she stalks turns out to be a highly evolved alien predator with a technically advanced arsenal.', 'vote_average': 7.853}, {'title': 'The Man from Toronto', 'id': 667739, 'overview': 'In a case of mistaken identity, the world’s deadliest assassin, known as the Man from Toronto, and a New York City screw-up are forced to team up after being confused for each other at a rental cabin.', 'vote_average': 6.574}, {'title': 'Thor: Love and Thunder', 'id': 616037, 'overview': 'After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor Odinson enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher’s vengeance and stop him before it’s too late.', 'vote_average': 6.689}, {'title': 'Dragon Knight', 'id': 919355, 'overview': "Many years after the war has been lost, and all the dragons slain, a lone knight travels the lands of Agonos seeking to raise an army against the demon lord Abaddon. When a healer's vision reveals that one dragon still lives, and together with an eager young squire, the knight sets off in search of the fabled creature. As the armies of Abaddon descend on the human kingdoms, the dragon is their last hope of fending off the horde, before it lays waste to the lands of men. But does the creature even exist? And if it does, will it fight for them once more?", 'vote_average': 7.125}, {'title': 'Day Shift', 'id': 755566, 'overview': "An LA vampire hunter has a week to come up with the cash to pay for his kid's tuition and braces. Trying to make a living these days just might kill him.", 'vote_average': 6.953}, {'title': 'The Sea Beast', 'id': 560057, 'overview': 'The life of a legendary sea monster hunter is turned upside down when a young girl stows away on his ship.', 'vote_average': 7.602}, {'title': 'The Black Phone', 'id': 756999, 'overview': 'Finney Blake, a shy but clever 13-year-old boy, is abducted by a sadistic killer and trapped in a soundproof basement where screaming is of little use. When a disconnected phone on the wall begins to ring, Finney discovers that he can hear the voices of the killer’s previous victims. And they are dead set on making sure that what happened to them doesn’t happen to Finney.', 'vote_average': 7.844}, {'title': 'Top Gun: Maverick', 'id': 361743, 'overview': 'After more than thirty years of service as one of the Navy’s top aviators, and dodging the advancement in rank that would ground him, Pete “Maverick” Mitchell finds himself training a detachment of TOP GUN graduates for a specialized mission the likes of which no living pilot has ever seen.', 'vote_average': 8.345}, {'title': 'Not Okay', 'id': 838330, 'overview': 'An ambitious young woman, desperate for followers and fame, fakes a trip to Paris to up her social media presence. When a terrifying incident takes place in the real world and becomes part of her imaginary trip, her white lie becomes a moral quandary ...

# %%
import pandas as pd
movie_df = pd.DataFrame(recommen)
movie_df.columns = ["title","id", "overview", "vote_average"]
movie_df
# Out:
#                        title       id  \
# 0               The Princess   759175
# 1       Adanis: Kutsal Kavga   978436
# 2    Jurassic World Dominion   507086
# 3                       Prey   766507
# 4       The Man from Toronto   667739
# 5     Thor: Love and Thunder   616037
# 6              Dragon Knight   919355
# 7                  Day Shift   755566
# 8              The Sea Beast   560057
# 9            The Black Phone   756999
# 10         Top Gun: Maverick   361743
# 11                  Not Okay   838330
# 12                   Shut In   629015
# 13                Persuasion   820912
# 14               Candlelight  1014444
# 15                 Lightyear   718789
# 16  Minions: The Rise of Gru   438148
# 17  They Still Call Me Bruce    65522
# 18        Valley of the Dead   613093
# 19              Bullet Train   718930
# 20              The Entitled   994006
#
#                                              overview  vote_average
# 0   A beautiful, strong-willed young royal refuses...         6.920
# 1                                                             5.167
# 2   Four years after the destruction of Isla Nubla...         6.966
# 3   When danger threatens her camp, the fierce and...         7.853
# 4   In a case of mistaken identity, the world’s de...         6.574
# 5   After his retirement is interrupted by Gorr th...         6.689
# 6   Many years after the war has been lost, and al...         7.125
# 7   An LA vampire hunter has a week to come up wit...         6.953
# 8   The life of a legendary sea monster hunter is ...         7.602
# 9   Finney Blake, a shy but clever 13-year-old boy...         7.844
# 10  After more than thirty years of service as one...         8.345
# 11  An ambitious young woman, desperate for follow...         6.428
# 12  A young single mother is held captive along wi...         7.093
# 13  Living with her snobby family on the brink of ...         5.938
# 14  Two candles meet and fall in love, but discove...        10.000
# 15  Legendary Space Ranger Buzz Lightyear embarks ...         7.191
# 16  A fanboy of a supervillain supergroup known as...         7.518
# 17  Bruce Won arrives in America in search of an A...         5.000
# 18  During the Spanish Civil War, sworn enemies mu...         6.247
# 19  Unlucky assassin Ladybug is determined to do h...         7.517
# 20  Suddenly catapulted into high society, a young...         4.700

# %% [markdown]
# ###Similar Movies

# %%
base_url = f'https://api.themoviedb.org/3/movie/{movie_id}/similar?api_key=e93793ba5e52b020648e1f1544b82e55&language=en-US&page=1'
headers = {'Authorization': token, 'User-Agent': 'TMDB App'}
response = requests.get(base_url, headers=headers)
similar = response.json()

# %%
pprint(similar)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/3HmLKhahTxX2ALTWlagr92pZrU7.jpg',
#               'genre_ids': [18],
#               'id': 462,
#               'original_language': 'en',
#               'original_title': 'Erin Brockovich',
#               'overview': 'A twice-divorced mother of three who sees an '
#                           'injustice, takes on the bad guy and wins -- with a '
#                           'little help from her push-up bra. Erin goes to work '
#                           'for an attorney and comes across medical records '
#                           'describing illnesses clustered in one nearby town. '
#                           'She starts investigating and soon exposes a '
#                           'monumental cover-up.',
#               'popularity': 19.922,
#               'poster_path': '/5GAUaXxC7chmHzXiB4L1nnplx9y.jpg',
#               'release_date': '2000-03-17',
#               'title': 'Erin Brockovich',
#               'video': False,
#               'vote_average': 7.412,
#               'vote_count': 2621},
#              {'adult': False,
#               'backdrop_path': '/8lBcqakI3F19NWkXdqE0M8W76b9.jpg',
#               'genre_ids': [28, 18, 36, 10752],
#               'id': 197,
#               'original_language': 'en',
#               'original_title': 'Braveheart',
#               'overview': 'Enraged at the slaughter of Murron, his new bride '
#                           'and childhood love, Scottish warrior William '
#                           "Wallace slays a platoon of the local English lord's "
#                           'soldiers. This leads the village to revolt and, '
#                           'eventually, the entire country to rise up against '
#                           'English rule.',
#               'popularity': 40.633,
#               'poster_path': '/or1gBugydmjToAEq7OZY0owwFk.jpg',
#               'release_date': '1995-03-14',
#               'title': 'Braveheart',
#               'video': False,
#               'vote_average': 7.927,
#               'vote_count': 8736},
#              {'adult': False,
#               'backdrop_path': '/aXKUodFZfaMMm2nM4rdekrNgvE2.jpg',
#               'genre_ids': [12, 18, 37],
#               'id': 581,
#               'original_language': 'en',
#               'original_title': 'Dances with Wolves',
#               'overview': 'Wounded Civil War soldier, John Dunbar tries to '
#                           'commit suicide—and becomes a hero instead. As a '
#                           "reward, he's assigned to his dream post, a remote "
#                           'junction on the Western frontier, and soon makes '
#                           'unlikely friends with the local Sioux tribe.',
#               'popularity': 31.586,
#               'poster_path': '/cvaBVpS0GzKqBd63pFT8f1E8OKv.jpg',
#               'release_date': '1990-03-30',
#               'title': 'Dances with Wolves',
#               'video': False,
#               'vote_average': 7.858,
#               'vote_count': 3541},
#              {'adult': False,
#               'backdrop_path': '/mcGCoUn02yCQbv2dPJt6JFiiy3k.jpg',
#               'genre_ids': [28, 80, 18],
#               'id': 9766,
#               'original_language': 'en',
#               'original_title': 'Gridiron Gang',
#               'overview': 'Teenagers at a juvenile detention center, under the '
#                           'leadership of their counselor, gain self-esteem by '
#                           'playing football together.',
#               'popularity': 26.708,
#               'poster_path': '/icv6qe7nhiGV914nf1WEr8wHy7m.jpg',
#               'release_date': '2006-09-15',
#               'title': 'Gridiron Gang',
#               'video': False,
#               'vote_average': 6.996,
#               'vote_count': 814},
#              {'adult': False,
#               'backdrop_path': '/e23ip5v7Iw43Fv5HcyGDBrRHApt.jpg',
#               'genre_ids': [12, 18, 53],
#               'id': 7305,
#               'original_language': 'en',
#               'original_title': 'Alive',
#               'overview': "The amazing, true story of a Uruguayan rugby team's "
#                           'plane that crashed in the middle of the Andes '
#                           'mountains, and their immense will to survive and '
#                           'pull through alive, forced to do anything and '
#                           'everything they could to stay alive on meager '
#                           'rations and through the freezing cold.',
#               'popularity': 23.043,
#               'poster_path': '/uQACcCZqd7WCTRin9xRIW5gr1bd.jpg',
#               'release_date': '1993-01-15',
#               'title': 'Alive',
#               'video': False,
#               'vote_average': 6.869,
#               'vote_count': 1203},
#              {'adult': False,
#               'backdrop_path': '/xEXojxR2GX40mSuCtA5IzR4Ev8a.jpg',
#               'genre_ids': [16, 14, 878],
#               'id': 8953,
#               'original_language': 'ja',
#               'original_title': 'スチームボーイ',
#               'overview': 'After receiving a package from his grandfather, '
#                           'Ray, a young inventor who lives in England during '
#                           'the mid-19th century, finds himself caught in the '
#                           'middle of a deadly conflict related to a '
#                           'revolutionary advance in steam power.',
#               'popularity': 18.732,
#               'poster_path': '/qYZUDELDUKYAhEw71ipeCtOFewc.jpg',
#               'release_date': '2004-07-17',
#               'title': 'Steamboy',
#               'video': False,
#               'vote_average': 6.831,
#               'vote_count': 314},
#              {'adult': False,
#               'backdrop_path': '/1bKaYqiSKO0vNdYOwZBhVNesViq.jpg',
#               'genre_ids': [18, 28],
#               'id': 7549,
#               'original_language': 'zh',
#               'original_title': '霍元甲',
#               'overview': 'Huo Yuan Jia became the most famous martial arts '
#                           'fighter in all of China at the turn of the 20th '
#                           'Century. Huo faced personal tragedy but ultimately '
#                           'fought his way out of darkness, defining the true '
#                           'spirit of martial arts and also inspiring his '
#                           "nation. The son of a great fighter who didn't wish "
#                           'for his child to follow in his footsteps, Huo '
#                           'resolves to teach himself how to fight - and win.',
#               'popularity': 24.642,
#               'poster_path': '/yKJ7rjIwOa8XvACELo9eV8IvMPb.jpg',
#               'release_date': '2006-01-26',
#               'title': 'Fearless',
#               'video': False,
#               'vote_average': 7.492,
#               'vote_count': 1053},
#              {'adult': False,
#               'backdrop_path': '/82ZXnrTOcNOm1NjWAWrSROQMULc.jpg',
#               'genre_ids': [12, 28, 35, 37],
#               'id': 8584,
#               'original_language': 'en',
#               'original_title': 'Shanghai Noon',
#               'overview': 'Chon Wang, a clumsy imperial guard trails Princess '
#                           'Pei Pei when she is kidnapped from the Forbidden '
#                           'City and transported to America. Wang follows her '
#                           'captors to Nevada, where he teams up with an '
#                           "unlikely partner, outcast outlaw Roy O'Bannon, and "
#                           'tries to spring the princess from her imprisonment.',
#               'popularity': 22.656,
#               'poster_path': '/b0WwWRcDiDahkah5vZ0KjB4N9ZZ.jpg',
#               'release_date': '2000-05-26',
#               'title': 'Shanghai Noon',
#               'video': False,
#               'vote_average': 6.399,
#               'vote_count': 2152},
#              {'adult': False,
#               'backdrop_path': '/m11Mej9vbQqcXWgYrgPboCJ9NUh.jpg',
#               'genre_ids': [12, 18, 10752],
#               'id': 8619,
#               'original_language': 'en',
#               'original_title': 'Master and Commander: The Far Side of the '
#                                 'World',
#               'overview': 'After an abrupt and violent encounter with a French '
#                           'warship inflicts severe damage upon his ship, a '
#                           'captain of the British Royal Navy begins a chase '
#                           'over two oceans to capture or destroy the enemy, '
#                           'though he must weigh his commitment to duty and '
#                           'ferocious pursuit of glory against the safety of '
#                           "his devoted crew, including the ship's thoughtful "
#                           'surgeon, his best friend.',
#               'popularity': 20.78,
#               'poster_path': '/s1cVTQEZYn4nSjZLnFbzLP0j8y2.jpg',
#               'release_date': '2003-11-14',
#               'title': 'Master and Commander: The Far Side of the World',
#               'video': False,
#               'vote_average': 7.099,
#               'vote_count': 2611},
#              {'adult': False,
#               'backdrop_path': '/t6fQaSbnYF4NLtf7QiebFDHP4Sr.jpg',
#               'genre_ids': [18, 36, 10752, 53, 9648],
#               'id': 8665,
#               'original_language': 'en',
#               'original_title': 'K-19: The Widowmaker',
#               'overview': "When Russia's first nuclear submarine malfunctions "
#                           'on its maiden voyage, the crew must race to save '
#                           'the ship and prevent a nuclear disaster.',
#               'popularity': 15.516,
#               'poster_path': '/ji7YWKx40TM8YexbRqfJZKMhQY3.jpg',
#               'release_date': '2002-07-19',
#               'title': 'K-19: The Widowmaker',
#               'video': False,
#               'vote_average': 6.459,
#               'vote_count': 810},
#              {'adult': False,
#               'backdrop_path': '/dlyeSZD92Arha6XVBteyNNaPi19.jpg',
#               'genre_ids': [12, 28, 35, 53],
#               'id': 8697,
#               'original_language': 'cn',
#               'original_title': '我是誰',
#               'overview': 'A group of covert CIA operatives trailing a '
#                           'potential new energy source are double-crossed by '
#                           'corrupt agent Morgan, who causes a helicopter crash '
#                           'in remote South Africa. The sole survivor, '
#                           'suffering severe amnesia, is nursed to recovery by '
#                           'a kindly native tribe who call him "Whoami" after '
#                           'the question he keeps asking. With the help of a '
#                           'mysterious reporter Christine, Whoami pieces '
#                           'together his past and tracks the turncoat agent and '
#                           'his criminal cohorts.',
#               'popularity': 21.599,
#               'poster_path': '/9YDKLbBmWGpxG5bO3TBawtNNOAr.jpg',
#               'release_date': '1998-01-17',
#               'title': 'Who Am I?',
#               'video': False,
#               'vote_average': 7.105,
#               'vote_count': 701},
#              {'adult': False,
#               'backdrop_path': '/h5Y9T4OoFpMrONhVBZvN2X2DfAB.jpg',
#               'genre_ids': [80, 35, 12],
#               'id': 9273,
#               'original_language': 'en',
#               'original_title': 'Ace Ventura: When Nature Calls',
#               'overview': 'Summoned from an ashram in Tibet, Ace finds himself '
#                           'on a perilous journey into the jungles of Africa to '
#                           'find Shikaka, the missing sacred animal of the '
#                           'friendly Wachati tribe. He must accomplish this '
#                           "before the wedding of the Wachati's Princess to the "
#                           'prince of the warrior Wachootoos. If Ace fails, the '
#                           'result will be a vicious tribal war.',
#               'popularity': 25.868,
#               'poster_path': '/wcinCf1ov2D6M3P7BBZkzQFOiIb.jpg',
#               'release_date': '1995-11-10',
#               'title': 'Ace Ventura: When Nature Calls',
#               'video': False,
#               'vote_average': 6.307,
#               'vote_count': 3532},
#              {'adult': False,
#               'backdrop_path': '/eeI3ZWOA88nG4YK5cMX6HnjXiEH.jpg',
#               'genre_ids': [10749, 27],
#               'id': 6114,
#               'original_language': 'en',
#               'original_title': "Bram Stoker's Dracula",
#               'overview': 'When Dracula leaves the captive Jonathan Harker and '
#                           'Transylvania for London in search of Mina Murray, '
#                           "the reincarnation of Dracula's long-dead wife "
#                           'Elisabeta, obsessed vampire hunter Dr. Van Helsing '
#                           'sets out to end the madness.',
#               'popularity': 35.078,
#               'poster_path': '/scFDS0U5uYAjcVTyjNc7GmcZw1q.jpg',
#               'release_date': '1992-11-13',
#               'title': "Bram Stoker's Dracula",
#               'video': False,
#               'vote_average': 7.441,
#               'vote_count': 4265},
#              {'adult': False,
#               'backdrop_path': '/mYnU5LqkCjWJLGSp9Oabbdq1GlI.jpg',
#               'genre_ids': [10752],
#               'id': 9289,
#               'original_language': 'en',
#               'original_title': 'The Longest Day',
#               'overview': 'The retelling of June 6, 1944, from the '
#                           'perspectives of the Germans, US, British, '
#                           'Canadians, and the Free French. Marshall Erwin '
#                           'Rommel, touring the defenses being established as '
#                           "part of the Reich's Atlantic Wall, notes to his "
#                           'officers that when the Allied invasion comes they '
#                           'must be stopped on the beach. "For the Allies as '
#                           'well as the Germans, it will be the longest day"',
#               'popularity': 16.647,
#               'poster_path': '/5zmvEofdIlgXrQl9A7e5IOzlnFU.jpg',
#               'release_date': '1962-09-25',
#               'title': 'The Longest Day',
#               'video': False,
#               'vote_average': 7.584,
#               'vote_count': 783},
#              {'adult': False,
#               'backdrop_path': '/ynnarxTMs8jWKV9GK0SpUhGNCgH.jpg',
#               'genre_ids': [53, 80, 18],
#               'id': 8848,
#               'original_language': 'en',
#               'original_title': 'The Bank Job',
#               'overview': 'Terry is a small-time car dealer trying to leave '
#                           'his shady past behind and start a family. Martine '
#                           "is a beautiful model from Terry's old neighbourhood "
#                           'who knows that Terry is no angel. When Martine '
#                           'proposes a foolproof plan to rob a bank, Terry '
#                           'recognises the danger but realises this may be the '
#                           'opportunity of a lifetime. As the resourceful band '
#                           'of thieves burrows its way into a safe-deposit '
#                           'vault at a Lloyds Bank, they quickly realise that, '
#                           'besides millions in riches, the boxes also contain '
#                           "secrets that implicate everyone from London's most "
#                           'notorious underworld gangsters to powerful '
#                           'government figures, and even the Royal Family. '
#                           'Although the heist makes headlines throughout '
#                           'Britain for several days, a government gag order '
#                           'eventually brings all reporting of the case to an '
#                           'immediate halt.',
#               'popularity': 27.224,
#               'poster_path': '/ayrGDJDsSBczjztGUWKqmzL97xg.jpg',
#               'release_date': '2008-02-28',
#               'title': 'The Bank Job',
#               'video': False,
#               'vote_average': 6.811,
#               'vote_count': 1877},
#              {'adult': False,
#               'backdrop_path': '/lVrUhaURUHStrl3mr15zkKplavB.jpg',
#               'genre_ids': [18, 35],
#               'id': 7350,
#               'original_language': 'en',
#               'original_title': 'The Bucket List',
#               'overview': 'Corporate billionaire Edward Cole and working class '
#                           'mechanic Carter Chambers are worlds apart. At a '
#                           'crossroads in their lives, they share a hospital '
#                           'room and discover they have two things in common: a '
#                           'desire to spend the time they have left doing '
#                           'everything they ever wanted to do and an unrealized '
#                           'need to come to terms with who they are. Together '
#                           'they embark on the road trip of a lifetime, '
#                           'becoming friends along the way and learning to live '
#                           'life to the fullest, with insight and humor.',
#               'popularity': 20.992,
#               'poster_path': '/idbNSe8zsYKQL97dJApfOrDSdya.jpg',
#               'release_date': '2007-12-15',
#               'title': 'The Bucket List',
#               'video': False,
#               'vote_average': 7.154,
#               'vote_count': 3242},
#              {'adult': False,
#               'backdrop_path': '/z5LhR3cqKIL0atMcNd16s4IP2kQ.jpg',
#               'genre_ids': [80, 18, 53],
#               'id': 1830,
#               'original_language': 'en',
#               'original_title': 'Lord of War',
#               'overview': 'Yuri Orlov is a globetrotting arms dealer and, '
#                           'through some of the deadliest war zones, he '
#                           'struggles to stay one step ahead of a relentless '
#                           'Interpol agent, his business rivals and even some '
#                           "of his customers who include many of the world's "
#                           'most notorious dictators. Finally, he must also '
#                           'face his own conscience.',
#               'popularity': 50.558,
#               'poster_path': '/wsy2d3072xsJpzYiP85BQOcD3gK.jpg',
#               'release_date': '2005-09-16',
#               'title': 'Lord of War',
#               'video': False,
#               'vote_average': 7.264,
#               'vote_count': 3941},
#              {'adult': False,
#               'backdrop_path': '/rPm9FhnsGMwZnbeHe4zRfW7nub8.jpg',
#               'genre_ids': [18, 36],
#               'id': 1887,
#               'original_language': 'en',
#               'original_title': 'Marie Antoinette',
#               'overview': "A retelling of France's iconic but ill-fated queen, "
#                           'Marie Antoinette, from her betrothal and marriage '
#                           'to Louis XVI at 15 to her reign as queen at 19 and '
#                           'ultimately the fall of Versailles.',
#               'popularity': 22.271,
#               'poster_path': '/cybXGmv8Rjd5Os8Xml6YxMBQ0Zt.jpg',
#               'release_date': '2006-05-24',
#               'title': 'Marie Antoinette',
#               'video': False,
#               'vote_average': 6.658,
#               'vote_count': 2306},
#              {'adult': False,
#               'backdrop_path': '/vhamaqMAkSphsGGAYt5ggeuPGK6.jpg',
#               'genre_ids': [18],
#               'id': 3558,
#               'original_language': 'en',
#               'original_title': 'Girl, Interrupted',
#               'overview': 'Set in the changing world of the late 1960s, '
#                           'Susanna Kaysen\'s prescribed "short rest" from a '
#                           'psychiatrist she had met only once becomes a '
#                           "strange, unknown journey into Alice's Wonderland, "
#                           'where she struggles with the thin line between '
#                           'normal and crazy. Susanna soon realizes how hard it '
#                           'is to get out once she has been committed, and she '
#                           'ultimately has to choose between the world of '
#                           'people who belong inside or the difficult world of '
#                           'reality outside.',
#               'popularity': 26.88,
#               'poster_path': '/dOBdatHIVppvmRFw2z7bf9VKJr9.jpg',
#               'release_date': '1999-03-24',
#               'title': 'Girl, Interrupted',
#               'video': False,
#               'vote_average': 7.551,
#               'vote_count': 3164},
#              {'adult': False,
#               'backdrop_path': '/dompWVgGL1qZ84BkQMlxGwOhKb8.jpg',
#               'genre_ids': [10749, 35, 18],
#               'id': 3573,
#               'original_language': 'en',
#               'original_title': 'Emma',
#               'overview': 'Emma Woodhouse is a congenial young lady who '
#                           'delights in meddling in other people’s affairs. She '
#                           'is perpetually trying to unite men and women who '
#                           'are utterly wrong for each other. Despite her '
#                           'interest in romance, Emma is clueless about her own '
#                           'feelings, and her relationship with gentle Mr. '
#                           'Knightly.',
#               'popularity': 14.382,
#               'poster_path': '/k1RXXkdEs8hDEgeLXPgCUebzs8n.jpg',
#               'release_date': '1996-08-02',
#               'title': 'Emma',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 513}],
#  'total_pages': 500,
#  'total_results': 10000}

# %%
# Get the list of movies from the results field
movies = similar["results"]

# Create an empty list to store the movie information
sim = []

# Iterate over the list of movies
for movie in movies:
    # Get the id, title, and overview of the current movie
    movie_title = movie["title"]
    movie_id = movie["id"]
    movie_overview = movie["overview"]
    vote_average = movie['vote_average']
    
    # Create a dictionary with the id, title, and overview of the current movie
    current_movie = {
        "title": movie_title,
        "id": movie_id,
        "overview": movie_overview,
        "vote_average": vote_average
    }
    
    # Add the movie information to the list of movie info
    sim.append(current_movie)

# Print the list of movie info
print(sim)
# Out:
# [{'title': 'Erin Brockovich', 'id': 462, 'overview': 'A twice-divorced mother of three who sees an injustice, takes on the bad guy and wins -- with a little help from her push-up bra. Erin goes to work for an attorney and comes across medical records describing illnesses clustered in one nearby town. She starts investigating and soon exposes a monumental cover-up.', 'vote_average': 7.412}, {'title': 'Braveheart', 'id': 197, 'overview': "Enraged at the slaughter of Murron, his new bride and childhood love, Scottish warrior William Wallace slays a platoon of the local English lord's soldiers. This leads the village to revolt and, eventually, the entire country to rise up against English rule.", 'vote_average': 7.927}, {'title': 'Dances with Wolves', 'id': 581, 'overview': "Wounded Civil War soldier, John Dunbar tries to commit suicide—and becomes a hero instead. As a reward, he's assigned to his dream post, a remote junction on the Western frontier, and soon makes unlikely friends with the local Sioux tribe.", 'vote_average': 7.858}, {'title': 'Gridiron Gang', 'id': 9766, 'overview': 'Teenagers at a juvenile detention center, under the leadership of their counselor, gain self-esteem by playing football together.', 'vote_average': 6.996}, {'title': 'Alive', 'id': 7305, 'overview': "The amazing, true story of a Uruguayan rugby team's plane that crashed in the middle of the Andes mountains, and their immense will to survive and pull through alive, forced to do anything and everything they could to stay alive on meager rations and through the freezing cold.", 'vote_average': 6.869}, {'title': 'Steamboy', 'id': 8953, 'overview': 'After receiving a package from his grandfather, Ray, a young inventor who lives in England during the mid-19th century, finds himself caught in the middle of a deadly conflict related to a revolutionary advance in steam power.', 'vote_average': 6.831}, {'title': 'Fearless', 'id': 7549, 'overview': "Huo Yuan Jia became the most famous martial arts fighter in all of China at the turn of the 20th Century. Huo faced personal tragedy but ultimately fought his way out of darkness, defining the true spirit of martial arts and also inspiring his nation. The son of a great fighter who didn't wish for his child to follow in his footsteps, Huo resolves to teach himself how to fight - and win.", 'vote_average': 7.492}, {'title': 'Shanghai Noon', 'id': 8584, 'overview': "Chon Wang, a clumsy imperial guard trails Princess Pei Pei when she is kidnapped from the Forbidden City and transported to America. Wang follows her captors to Nevada, where he teams up with an unlikely partner, outcast outlaw Roy O'Bannon, and tries to spring the princess from her imprisonment.", 'vote_average': 6.399}, {'title': 'Master and Commander: The Far Side of the World', 'id': 8619, 'overview': "After an abrupt and violent encounter with a French warship inflicts severe damage upon his ship, a captain of the British Royal Navy begins a chase over two oceans to capture or destroy the enemy, though he must weigh his commitment to duty and ferocious pursuit of glory against the safety of his devoted crew, including the ship's thoughtful surgeon, his best friend.", 'vote_average': 7.099}, {'title': 'K-19: The Widowmaker', 'id': 8665, 'overview': "When Russia's first nuclear submarine malfunctions on its maiden voyage, the crew must race to save the ship and prevent a nuclear disaster.", 'vote_average': 6.459}, {'title': 'Who Am I?', 'id': 8697, 'overview': 'A group of covert CIA operatives trailing a potential new energy source are double-crossed by corrupt agent Morgan, who causes a helicopter crash in remote South Africa. The sole survivor, suffering severe amnesia, is nursed to recovery by a kindly native tribe who call him "Whoami" after the question he keeps asking. With the help of a mysterious reporter Christine, Whoami pieces together his past and tracks the turncoat agent and his criminal cohorts.', 'vote_average': 7.105}, {'title': 'Ace  ...

# %%
import pandas as pd
movie_df = pd.DataFrame(sim)
movie_df.columns = ["title","id", "overview", "vote_average"]
movie_df
# Out:
#                                               title    id  \
# 0                                   Erin Brockovich   462
# 1                                        Braveheart   197
# 2                                Dances with Wolves   581
# 3                                     Gridiron Gang  9766
# 4                                             Alive  7305
# 5                                          Steamboy  8953
# 6                                          Fearless  7549
# 7                                     Shanghai Noon  8584
# 8   Master and Commander: The Far Side of the World  8619
# 9                              K-19: The Widowmaker  8665
# 10                                        Who Am I?  8697
# 11                   Ace Ventura: When Nature Calls  9273
# 12                            Bram Stoker's Dracula  6114
# 13                                  The Longest Day  9289
# 14                                     The Bank Job  8848
# 15                                  The Bucket List  7350
# 16                                      Lord of War  1830
# 17                                 Marie Antoinette  1887
# 18                                Girl, Interrupted  3558
# 19                                             Emma  3573
#
#                                              overview  vote_average
# 0   A twice-divorced mother of three who sees an i...         7.412
# 1   Enraged at the slaughter of Murron, his new br...         7.927
# 2   Wounded Civil War soldier, John Dunbar tries t...         7.858
# 3   Teenagers at a juvenile detention center, unde...         6.996
# 4   The amazing, true story of a Uruguayan rugby t...         6.869
# 5   After receiving a package from his grandfather...         6.831
# 6   Huo Yuan Jia became the most famous martial ar...         7.492
# 7   Chon Wang, a clumsy imperial guard trails Prin...         6.399
# 8   After an abrupt and violent encounter with a F...         7.099
# 9   When Russia's first nuclear submarine malfunct...         6.459
# 10  A group of covert CIA operatives trailing a po...         7.105
# 11  Summoned from an ashram in Tibet, Ace finds hi...         6.307
# 12  When Dracula leaves the captive Jonathan Harke...         7.441
# 13  The retelling of June 6, 1944, from the perspe...         7.584
# 14  Terry is a small-time car dealer trying to lea...         6.811
# 15  Corporate billionaire Edward Cole and working ...         7.154
# 16  Yuri Orlov is a globetrotting arms dealer and,...         7.264
# 17  A retelling of France's iconic but ill-fated q...         6.658
# 18  Set in the changing world of the late 1960s, S...         7.551
# 19  Emma Woodhouse is a congenial young lady who d...         6.700
